# %%
dbutils.notebook.run(
    "jobs/bronze_ibge_estados",
    3600
)

dbutils.notebook.run(
    "jobs/bronze_ibge_municipios",
    3600
)

dbutils.notebook.run(
    "jobs/bronze_meta_alfabetizacao_brasil",
    3600
)

dbutils.notebook.run(
    "jobs/bronze_meta_alfabetizacao_municipio",
    3600
)

dbutils.notebook.run(
    "jobs/bronze_meta_alfabetizacao_uf",
    3600
)

dbutils.notebook.run(
    "jobs/bronze_uf",
    3600
)
