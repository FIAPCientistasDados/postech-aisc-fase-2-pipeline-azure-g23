# %%
# =========================
# Orquestrador Bronze
# =========================

import datetime as dt

print(
    f"🚀 Início da execução Bronze: "
    f"{dt.datetime.now()}"
)

# ------------------------------------------
# Estados IBGE
# ------------------------------------------

print("▶ Executando bronze_ibge_estados")

dbutils.notebook.run(
    "./bronze_ibge_estados",
    timeout_seconds=3600
)

# ------------------------------------------
# Municípios IBGE
# ------------------------------------------

print("▶ Executando bronze_ibge_municipios")

dbutils.notebook.run(
    "./bronze_ibge_municipios",
    timeout_seconds=3600
)

# ------------------------------------------
# INEP Alfabetização
# ------------------------------------------

print("▶ Executando bronze_inep_alfabetizacao")

dbutils.notebook.run(
    "./bronze_inep_alfabetizacao",
    timeout_seconds=3600
)

print(
    f"✅ Camada Bronze finalizada com sucesso: "
    f"{dt.datetime.now()}"
)
# Out:
# 🚀 Início da execução Bronze: 2026-08-23 23:58:23.349791
# ▶ Executando bronze_ibge_estados
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 18
#      14 # ------------------------------------------
#      15
#      16 print("▶ Executando bronze_ibge_estados")
#      17
# ---> 18 dbutils.notebook.run(
#      19     "./bronze_ibge_estados",
#      20     timeout_seconds=3600
#      21 )
#
# NameError: name 'dbutils' is not defined
